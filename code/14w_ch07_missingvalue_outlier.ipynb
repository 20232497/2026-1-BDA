# %% [markdown]
# <a href="https://colab.research.google.com/github/ai7dnn/2026-1-BDA/blob/main/code/14w_ch07_missingvalue_outlier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **빅데이터분석프로그래밍**

# %% [markdown]
# # 파이썬 설치 확인

# %%
import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

print(sys.version)
print(pd.__version__)
print(np.__version__)
print(sns.__version__)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# 2.2.2
# 2.0.2
# 0.13.2

# %% [markdown]
# # 코랩에서 한글 처리

# %%
# !pip install koreanize_matplotlib
import koreanize_matplotlib
# 그림 선명하게
# %config InlineBackend.figure_format = 'retina'
# Out:
# Collecting koreanize_matplotlib
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from koreanize_matplotlib) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->koreanize_matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.17.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 57.1 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
# 데이터프레임의 소수점 이하 n(2)자리 출력 설정
pd.set_option('display.precision', 2)

# %%
plt.rcParams['figure.figsize'] = (4, 2)

# %%
import matplotlib.pyplot as plt

plt.plot([-10, 5, -3, 1])
plt.title('그래프 제목')
plt.xlabel('직선')
plt.show()

# %%
from IPython.display import display_html
import inspect
import ast

def display_side_by_side(*dfs):
    titles = []

    try:
        caller_frame = inspect.currentframe().f_back
        call_line = inspect.getframeinfo(caller_frame).code_context[0].strip()

        tree = ast.parse(call_line)
        call = tree.body[0].value

        if isinstance(call, ast.Call):
            for arg in call.args:
                titles.append(ast.get_source_segment(call_line, arg))
    except:
        titles = [''] * len(dfs)

    if len(titles) < len(dfs):
        titles += [''] * (len(dfs) - len(titles))

    html_str = ''
    for df, title in zip(dfs, titles):
        html_str += f"""
        <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
            <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
                {title}
            </div>
            <div style="display:flex; justify-content:center;">
                {df.to_html()}
            </div>
        </div>
        """

    display_html(html_str, raw=True)

# %%
from IPython.display import display_html
import inspect
import ast

def display_series_side_by_side(*args):
    """여러 Series를 옆으로 나란히 표시하고,
    호출 시 사용한 표현식을 제목으로 위에 출력한다.
    """
    titles = []

    try:
        caller_frame = inspect.currentframe().f_back
        call_line = inspect.getframeinfo(caller_frame).code_context[0].strip()

        tree = ast.parse(call_line)
        call = tree.body[0].value

        if isinstance(call, ast.Call):
            for arg in call.args:
                titles.append(ast.get_source_segment(call_line, arg))
    except:
        titles = [''] * len(args)

    if len(titles) < len(args):
        titles += [''] * (len(args) - len(titles))

    html_str = ''
    for s, title in zip(args, titles):
        table_html = s.to_frame().to_html()

        html_str += f"""
        <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
            <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
                {title}
            </div>
            <div style="display:flex; justify-content:center;">
                {table_html}
            </div>
        </div>
        """

    display_html(html_str, raw=True)

# %% [markdown]
# ## 수업에서 사용할 데이터를 다음 깃에서 복사
# - https://github.com/ai7dnn/data.git
#
# > #### 수업에서 파일 사용 시
# > - 현재 하부 폴더: data
# > - 파일: data/파일이름

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 50 (delta 12), reused 1 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 5.71 MiB | 5.32 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
import pandas as pd

exam = pd.read_csv('data/exam.csv')
exam.head()
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58
# 4   5       2    25       80       65

# %% [markdown]
# # 07 데이터 정제  - 빠진 데이터, 이상한 데이터 제거하기

# %%
df = pd.DataFrame({'sex'   : ['M', 'F', np.nan, 'M', 'F'],
                   'score' : [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.score + 1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %% [markdown]
# #### 결측치 확인하기

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isnull()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
display_side_by_side(df.isna(), df.isnull())
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.isna()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.isnull()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
df.notna() # isnull() 반대
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %%
df.notnull()
# Out:
#      sex  score
# 0   True   True
# 1   True   True
# 2  False   True
# 3   True   True
# 4   True  False

# %%
display_side_by_side(df.notna(), df.notnull())
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.notna()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.notnull()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>True</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna().sum()
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# dtype: int64

# %%
s = pd.Series([True, True, False, True])
s
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s.sum()
# Out:
# np.int64(3)

# %%
s.any()
# Out:
# np.True_

# %%
bool(s.any())
# Out:
# True

# %%
s.all()
# Out:
# np.False_

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.isna()
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
df.isna().any(axis=0)
# Out:
# sex      True
# score    True
# dtype: bool

# %%
b = df.isna().any(axis=1)
b
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df[b] # NaN이 있는 행
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
# 적어도 NaN인 하나 있는 행을 추출
df[ df.isna().any(axis=1) ]
# Out:
#    sex  score
# 2  NaN    3.0
# 4    F    NaN

# %%
# NaN이 하나도 없는 행을 추출
df[ ~df.isna().any(axis=1) ]
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
# NaN이 하나도 없는 행을 추출
df[ df.notna().all(axis=1) ]
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# ### mumpy.isnan() 함수: 속도가 빠름
# - 수 값만 가능

# %%
df.score
# Out:
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN
# Name: score, dtype: float64

# %%
import numpy as np
np.isnan(df.score)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: score, dtype: bool

# %%
pd.isna(df.score)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: score, dtype: bool

# %% [markdown]
# ## 결측값 시각화
# - [패키지 missingno](https://github.com/ResidentMario/missingno)

# %%
display_side_by_side(df, df.isnull())
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.isnull()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>True</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>False</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>False</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
import seaborn as sns
sns.heatmap(df.isnull(), cbar=False);

# %%
sns.heatmap(df.isnull());

# %%
import missingno as msno
# 가로 5인치, 세로 2인치 크기로 지정
msno.matrix(df, figsize=(5, 2));

# %%
tdf = sns.load_dataset('titanic')
msno.matrix(tdf, figsize=(10, 5));

# %%
tdf2 = tdf.sample(20)
tdf2
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 331         0       1    male  45.5      0      0   28.50        S   First
# 672         0       2    male  70.0      0      0   10.50        S  Second
# 385         0       2    male  18.0      0      0   73.50        S  Second
# 744         1       3    male  31.0      0      0    7.92        S   Third
# 65          1       3    male   NaN      1      1   15.25        C   Third
# 26          0       3    male   NaN      0      0    7.22        C   Third
# 215         1       1  female  31.0      1      0  113.28        C   First
# 123         1       2  female  32.5      0      0   13.00        S  Second
# 155         0       1    male  51.0      0      1   61.38        C   First
# 355         0       3    male  28.0      0      0    9.50        S   Third
# 785         0       3    male  25.0      0      0    7.25        S   Third
# 555         0       1    male  62.0      0      0   26.55        S   First
# 625         0       1    male  61.0      0      0   32.32        S   First
# 259         1       2  female  50.0      0      1   26.00        S  Second
# 574         0       3    male  16.0      0      0    8.05        S   Third
# 429         1       3    male  32.0      0      0    8.05        S   Third
# 424         0       3    male  18.0      1      1   20.21        S   Third
# 190         1       2  female  32.0      0      0   13.00        S  Second
# 847         0       3    male  35.0      0      0    7.90        C   Third
# 730         1       1  female  29.0      0      0  211.34        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 331    man        True    C  Southampton    no   True
# 672    man        True  NaN  Southampton    no   True
# 385    man        True  NaN  Southampton    no   True
# 744    man        True  NaN  Southampton   yes   True
# 65     man        True  NaN    Cherbourg   yes  False
# 26     man        True  NaN    Cherbourg    no   True
# 215  woman       False    D    Cherbourg   yes  False
# 123  woman       False    E  Southampton   yes   True
# 155    man        True  NaN    Cherbourg    no  False
# 355    man        True  NaN  Southampton    no   True
# 785    man        True  NaN  Southampton    no   True
# 555    man        True  NaN  Southampton    no   True
# 625    man        True    D  Southampton    no   True
# 259  woman       False  NaN  Southampton   yes  False
# 574    man        True  NaN  Southampton    no   True
# 429    man        True    E  Southampton   yes   True
# 424    man        True  NaN  Southampton    no  False
# 190  woman       False  NaN  Southampton   yes   True
# 847    man        True  NaN    Cherbourg    no   True
# 730  woman       False    B  Southampton   yes   True

# %%
msno.matrix(tdf2, figsize=(10, 3));

# %% [markdown]
# - 오른쪽의 스파크라인은 각 행에서 결측값이 없는 수를 연결한 라인 모양을 요약
#     - 행마다 15개중 결측값(NaN)이 아닌 정상적인 데이터의 수를 나타냄
#     - 15는 모두 정상값, 13은 2개가 결측값이 있는 행
#     - 그 점을 다음 행과 연결한 선

# %%
# 열 embarked가 NaN인 행 추출
tdf[ tdf.embarked.isna() ]
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone
# 61   woman       False    B         NaN   yes   True
# 829  woman       False    B         NaN   yes   True

# %%
# 두 열, age, deck이 모두 NaN인 행 추출
tdf[ (tdf.age.isna()) & (tdf.deck.isna()) ]
# Out:
#      survived  pclass     sex  age  sibsp  parch   fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.46        Q   Third
# 17          1       2    male  NaN      0      0  13.00        S  Second
# 19          1       3  female  NaN      0      0   7.22        C   Third
# 26          0       3    male  NaN      0      0   7.22        C   Third
# 28          1       3  female  NaN      0      0   7.88        Q   Third
# ..        ...     ...     ...  ...    ...    ...    ...      ...     ...
# 859         0       3    male  NaN      0      0   7.23        C   Third
# 863         0       3  female  NaN      8      2  69.55        S   Third
# 868         0       3    male  NaN      0      0   9.50        S   Third
# 878         0       3    male  NaN      0      0   7.90        S   Third
# 888         0       3  female  NaN      1      2  23.45        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 5      man        True  NaN   Queenstown    no   True
# 17     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN    Cherbourg   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 28   woman       False  NaN   Queenstown   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [158 rows x 15 columns]

# %%
# 세 개 열, age, deck, embark_town이 모두 NaN인 행 추출
tdf[ (tdf.age.isna()) & (tdf.deck.isna()) & (tdf.embark_town.isna()) ]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone]
# Index: []

# %%
# 최소한 1개의 NaN에 있는 행 추출
tdf[tdf.isna().any(axis=1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.25        S   Third
# 2           1       3  female  26.0      0      0   7.92        S   Third
# 4           0       3    male  35.0      0      0   8.05        S   Third
# 5           0       3    male   NaN      0      0   8.46        Q   Third
# 7           0       3    male   2.0      3      1  21.07        S   Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...     ...
# 884         0       3    male  25.0      0      0   7.05        S   Third
# 885         0       3  female  39.0      0      5  29.12        Q   Third
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [709 rows x 15 columns]

# %%
# 최소한 1개의 NaN에 있는 행 추출
tdf.drop( tdf.dropna().index )
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.25        S   Third
# 2           1       3  female  26.0      0      0   7.92        S   Third
# 4           0       3    male  35.0      0      0   8.05        S   Third
# 5           0       3    male   NaN      0      0   8.46        Q   Third
# 7           0       3    male   2.0      3      1  21.07        S   Third
# ..        ...     ...     ...   ...    ...    ...    ...      ...     ...
# 884         0       3    male  25.0      0      0   7.05        S   Third
# 885         0       3  female  39.0      0      5  29.12        Q   Third
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 2    woman       False  NaN  Southampton   yes   True
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [709 rows x 15 columns]

# %%
tdf.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.28        C  First
# 3           1       1  female  35.0      1      0  53.10        S  First
# 6           0       1    male  54.0      0      0  51.86        S  First
# 10          1       3  female   4.0      1      1  16.70        S  Third
# 11          1       1  female  58.0      0      0  26.55        S  First
# ..        ...     ...     ...   ...    ...    ...    ...      ...    ...
# 871         1       1  female  47.0      1      1  52.55        S  First
# 872         0       1    male  33.0      0      0   5.00        S  First
# 879         1       1  female  56.0      0      1  83.16        C  First
# 887         1       1  female  19.0      0      0  30.00        S  First
# 889         1       1    male  26.0      0      0  30.00        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
tdf.dropna().shape[0] + tdf.drop( tdf.dropna().index ).shape[0]
# Out:
# 891

# %%
tdf.shape[0]
# Out:
# 891

# %%
msno.bar(tdf, figsize=(10, 5), fontsize=12); # label_rotation=45

# %% [markdown]
# ### 결측치 제거하기

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna()
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %% [markdown]
# ### 인자 axis (제거할 방향 설정)
# - 결측치를 만났을 때, 행(Row)을 지울지 열(Column)을 지울지 결정합니다.
# - axis=0 또는 axis='index' (기본값): 결측치가 포함된 행을 통째로 지웁니다.
# - axis=1 또는 axis='columns' : 결측치가 포함된 열을 통째로 지웁니다.

# %% [markdown]
# ### 인자 subset (특정 컬럼/인덱스만 조준)
# - 데이터프레임 전체를 검사하는 것이 아니라, 지정한 특정 열(또는 행)들만 검사하여 결측치를 지웁니다. 실무에서 가장 유용하게 쓰이는 인자입니다.
# - 예시: df.dropna(subset=['Age', 'Score'])
#     - 다른 컬럼에 결측치가 아무리 많아도 무시하고, 오직 'Age'와 'Score' 컬럼에 결측치가 있는 행만 골라서 지웁니다.

# %%
df.dropna(subset=['sex'])
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0
# 4   F    NaN

# %%
display_side_by_side( df, df.dropna(subset=['sex']), df.dropna(subset=['score']) )
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(subset=['sex'])
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(subset=['score'])
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#       <td>4.0</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
df_nomiss = df.dropna(subset = ['score'])  # score 결측치 제거된 데이터 만들기
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss['score'] + 1                     # score로 연산
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df.dropna(subset=['sex'], axis=0)
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0
# 4   F    NaN

# %%
# 행 2에 NaN이 있으면 열을 제거
df.dropna(subset = [2], axis = 1)
# Out:
#    score
# 0    5.0
# 1    4.0
# 2    3.0
# 3    4.0
# 4    NaN

# %%
display_side_by_side(df, df.dropna(subset = [2], axis = 1), df.dropna(subset = [4], axis = 1))
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(subset = [2], axis = 1)
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>5.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(subset = [4], axis = 1)
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>F</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>M</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
# 행 3에 NaN이 있으면 열을 제거
df.dropna(subset = [3], axis = 1)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(axis = 1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(axis = 1).empty
# Out:
# True

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score'].mean() # 결측값은 제거(무시)하고 계산
# Out:
# np.float64(4.0)

# %%
df['score'].sum() # 결측값은 제거(무시)하고 계산
# Out:
# np.float64(16.0)

# %%
# 결측값은 제거(무시)하고 계산
df.groupby('sex').agg(mean_score = ('score', 'mean'),
                      sum_score  = ('score', 'sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %% [markdown]
# ### pandas 문서: df.dropna()

# %%
df = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman', np.nan],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT]})
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True
# 3   True   True   True

# %%
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df[ df.notnull().all(axis=1) ]
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
# 결측값이 없는 행 출력
display_side_by_side(df, df.dropna(), df[ df.notnull().all(axis=1) ])
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df[ df.notnull().all(axis=1) ]
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
# 결측값이 있는 행 출력
display_side_by_side(df, df.drop( df.dropna().index ), df[ df.isnull().any(axis=1) ])
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.drop( df.dropna().index )
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df[ df.isnull().any(axis=1) ]
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
df.dropna(axis='columns') # 아무 것도 없는 빈 데이터프레임
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
# 모든 값이 NaN인 경우, 행 제거
display_side_by_side(df, df.dropna(how='all'))
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(how='all')
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %%
# 하나라도 NaN인 경우, 행 제거
display_side_by_side(df, df.dropna(how='any'), df.dropna())
# Out:
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alfred</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Catwoman</td>
#       <td>Bullwhip</td>
#       <td>NaT</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaT</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna(how='any')
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>
#
#         <div style="display:inline-block; vertical-align:top; margin-right:20px; text-align:center;">
#             <div style="font-weight:bold; font-size:13px; margin-bottom:8px; text-align:center;">
#                 df.dropna()
#             </div>
#             <div style="display:flex; justify-content:center;">
#                 <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>toy</th>
#       <th>born</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>Batman</td>
#       <td>Batmobile</td>
#       <td>1940-04-25</td>
#     </tr>
#   </tbody>
# </table>
#             </div>
#         </div>

# %% [markdown]
# ### 결측치 대체하기

# %%
exam = pd.read_csv('data/exam.csv')      # 데이터 불러오기
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam['math'].mean()
# Out:
# np.float64(55.23529411764706)

# %%
round(float(exam['math'].mean()), 2)
# Out:
# 55.24

# %% [markdown]
# ### 결측값 채워넣기 fillna()

# %%
exam['math'] = exam['math'].fillna(100)  # math가 NaN이면 55로 대체
exam                                     # 출력
# Out:
#     id  nclass   math  english  science
# 0    1       1   50.0       98       50
# 1    2       1   60.0       97       60
# 2    3       1  100.0       86       78
# 3    4       1   30.0       98       58
# 4    5       2   25.0       80       65
# 5    6       2   50.0       89       98
# 6    7       2   80.0       90       45
# 7    8       2  100.0       78       25
# 8    9       3   20.0       98       15
# 9   10       3   50.0       98       45
# 10  11       3   65.0       65       65
# 11  12       3   45.0       85       32
# 12  13       4   46.0       98       65
# 13  14       4   48.0       87       12
# 14  15       4  100.0       56       78
# 15  16       4   58.0       98       65
# 16  17       5   65.0       68       98
# 17  18       5   80.0       78       90
# 18  19       5   89.0       68       87
# 19  20       5   78.0       83       58

# %%
exam.loc[[2, 7, 14], ['math']] = np.nan  # 2, 7, 14행의 math에 NaN 할당
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
pd.set_option('display.precision', 2)
exam['math'] = exam['math'].fillna(exam['math'].mean())  # math가 NaN이면 55로 대체
exam
# Out:
#     id  nclass   math  english  science
# 0    1       1  50.00       98       50
# 1    2       1  60.00       97       60
# 2    3       1  55.24       86       78
# 3    4       1  30.00       98       58
# 4    5       2  25.00       80       65
# 5    6       2  50.00       89       98
# 6    7       2  80.00       90       45
# 7    8       2  55.24       78       25
# 8    9       3  20.00       98       15
# 9   10       3  50.00       98       45
# 10  11       3  65.00       65       65
# 11  12       3  45.00       85       32
# 12  13       4  46.00       98       65
# 13  14       4  48.00       87       12
# 14  15       4  55.24       56       78
# 15  16       4  58.00       98       65
# 16  17       5  65.00       68       98
# 17  18       5  80.00       78       90
# 18  19       5  89.00       68       87
# 19  20       5  78.00       83       58

# %% [markdown]
# ## 07-2 이상한 데이터를 찾아라! - 이상치 정제하기

# %%
df = pd.DataFrame({'sex'   : [1, 2, 1, 3, 2, 1],
                   'score' : [5, 4, 3, 4, 2, 6]})
df
# Out:
#    sex  score
# 0    1      5
# 1    2      4
# 2    1      3
# 3    3      4
# 4    2      2
# 5    1      6

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    3
# 2    2
# 3    1
# Name: count, dtype: int64

# %%
df['score'].value_counts()
# Out:
# score
# 4    2
# 5    1
# 3    1
# 2    1
# 6    1
# Name: count, dtype: int64

# %%
# sex가 3이면 NaN 부여
df['sex'] = np.where(df['sex'] == 3, np.nan, df['sex'])
df
# Out:
#    sex  score
# 0  1.0      5
# 1  2.0      4
# 2  1.0      3
# 3  NaN      4
# 4  2.0      2
# 5  1.0      6

# %%
# score가 5보다 크면 NaN 부여
df['score'] = np.where(df['score'] > 5, np.nan, df['score'])
df
# Out:
#    sex  score
# 0  1.0    5.0
# 1  2.0    4.0
# 2  1.0    3.0
# 3  NaN    4.0
# 4  2.0    2.0
# 5  1.0    NaN

# %%
# sex, score 결측치 제거
# sex별 분리
# score 평균 구하기
df.dropna(subset = ['sex', 'score']).groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df.dropna().groupby('sex').agg(mean_score = ('score', 'mean'))
# Out:
#      mean_score
# sex
# 1.0         4.0
# 2.0         3.0

# %%
df = pd.DataFrame({'x1' : [1, 1, 2, 2]})
df['x2'] = np.where(df['x1'] == 1, 10, np.nan)  # 조건에 맞으면 문자 부여
df
# Out:
#    x1    x2
# 0   1  10.0
# 1   1  10.0
# 2   2   NaN
# 3   2   NaN

# %% [markdown]
# ### 이상치 제거하기 - 극단적인 값

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 171       subaru          impreza awd    2.5  2008    4  manual(m5)   4   19
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 123         jeep   grand cherokee 4wd    3.7  2008    6    auto(l5)   4   15
# 196       toyota              corolla    1.8  2008    4  manual(m5)   f   28
# 209   volkswagen                  gti    2.0  2008    4  manual(m6)   f   21
#
#      hwy fl category
# 171   25  p  compact
# 69    12  e   pickup
# 123   19  r      suv
# 196   37  r  compact
# 209   29  p  compact

# %%
sns.boxplot(mpg, y = 'hwy');

# %% [markdown]
# ### 박스상자의 구성요소
# ![image.png](data:image/png;base64,...)

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s.quantile([.25, .5, .75])
# Out:
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# dtype: float64

# %%
s = pd.Series([1, 2, 4, 5])

# %%
s.quantile([.25, .5, .75])
# Out:
# 0.25    1.75
# 0.50    3.00
# 0.75    4.25
# dtype: float64

# %%
pct25, pct75 = mpg['hwy'].quantile([.25, .75])

# %%
pct25
# Out:
# 18.0

# %%
pct75
# Out:
# 27.0

# %% [markdown]
# #### IQR(Interquartile range) 구하기

# %%
iqr = pct75 - pct25
iqr
# Out:
# 9.0

# %% [markdown]
# #### 하한, 상한 구하기

# %%
pct25 - 1.5 * iqr  # 하한
# Out:
# 4.5

# %%
pct75 + 1.5 * iqr  # 상한
# Out:
# 40.5

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
import missingno as msno
msno.matrix(mpg, figsize=(10, 5));

# %% [markdown]
# ### 3. 이상값을 결측 처리하기

# %%
# 4.5 ~ 40.5 벗어나면 NaN 부여
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])

# 결측치 빈도 확인
mpg['hwy'].isna().sum()
# Out:
# 3

# %%
dmpg = mpg.dropna(subset = ['hwy'])
len(dmpg)
# Out:
# 231

# %%
dmpg.shape
# Out:
# (231, 11)

# %%
dmpg.dropna(subset = ['hwy']).groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy', 'mean'))
# Out:
#      mean_hwy
# drv
# 4      19.175
# f      27.728
# r      21.000

# %% [markdown]
# ## 종료
